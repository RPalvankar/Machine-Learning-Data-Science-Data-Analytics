# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.colors import ListedColormap

UF_network = np.load(r'C:\Users\ritvikpalvankar7\Desktop\FML\UF_network.npy')
X = UF_network[:,:2]
y = UF_network[:,2]

cm = ListedColormap(['blue', 'orange'])
plt.scatter(X[:,0],X[:,1],c=y, cmap=cm);
plt.xlabel('Feature 1')
plt.ylabel('Feature 2');

# %%
from sklearn.metrics import accuracy_score
from sklearn.neural_network import MLPClassifier

# Do not change these parameters
net = MLPClassifier(activation='tanh',
                    n_iter_no_change = 1000)

# %%
def plot_LC_and_DB(X, model):
    '''This function will plot the learning curve and decision boundary
    for a given trained model and training data X.
    model: is a sklearn model structure
    X: training data'''
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                             np.arange(y_min, y_max, 0.02))
    
    fig = plt.figure(figsize=(15,5))
    fig.add_subplot(1,2,1)
    plt.plot(model.loss_curve_)
    plt.title('Learning Curve')
    plt.xlabel('Epochs')
    plt.ylabel('Loss Function')

    cm = ListedColormap(['blue', 'orange'])
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape) 
    fig.add_subplot(1,2,2)
    plt.contourf(xx, yy, Z, cmap=cm, alpha=.8);
    plt.title('Decision Boundary')
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.show();

# %% [markdown]
# # 1: We use 16 and 6 units for first and second hidden layer respectively. 16 units are used for boundary creation of the letters. 6 units are used as we have that many number of convex shapes and also it is used for joining the boundaries.

# %% [markdown]
# # 2 : Same goal with single hidden layer cannot be achieved. The universal approximation theorem is used for approximation of a continuous function, but in this case as we're doing classification, we'll deal with discrete classes.

# %% [markdown]
# ### 3.1

# %%
# Create a list with your own set of values for all of these parameters
net_hidden_layers =[16,6] #
net_learning_rate =[0.3,0.3] #
epochs =[800,800]

for i in net_hidden_layers:
    for j in net_learning_rate:
        for k in epochs:
            net.set_params(hidden_layer_sizes = i, learning_rate_init = j, max_iter = k)
            net.fit(X, y)
            y_pred = net.predict(X)

            acc_score = accuracy_score(y, y_pred)
            print('-----------------------------------')
            print('Hidden Layer Architecture: ', i)
            print('Learning Rate: ', j)
            print('Number of Epochs: ', k)
            print('Accuracy = ', np.round(acc_score*100,2),'%')
            print('-----------------------------------')
            plot_LC_and_DB(X, net)
# Out:
# C:\Users\ritvikpalvankar7\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# -----------------------------------
# Hidden Layer Architecture:  16
# Learning Rate:  0.3
# Number of Epochs:  800
# Accuracy =  95.37 %
# -----------------------------------
# C:\Users\ritvikpalvankar7\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# -----------------------------------
# Hidden Layer Architecture:  16
# Learning Rate:  0.3
# Number of Epochs:  800
# Accuracy =  92.27 %
# -----------------------------------
# ...

# %%
from IPython.display import Image

# %% [markdown]
# ## Learning rate for the graph below is 0.3 and the epoch is 800 with accuracy=96.83%

# %%
Image(r'C:\Users\ritvikpalvankar7\Desktop\FML\fig1.png')

# %% [markdown]
# # 3.2

# %%
net_hidden_layers =[16,6] #
net_learning_rate =[0.09,0.09] #
epochs =[700,700]

for i in net_hidden_layers:
    for j in net_learning_rate:
        for k in epochs:
            net.set_params(hidden_layer_sizes = i, learning_rate_init = j, max_iter = k)
            net.fit(X, y)
            y_pred = net.predict(X)

            acc_score = accuracy_score(y, y_pred)
            print('-----------------------------------')
            print('Hidden Layer Architecture: ', i)
            print('Learning Rate: ', j)
            print('Number of Epochs: ', k)
            print('Accuracy = ', np.round(acc_score*100,2),'%')
            print('-----------------------------------')
            plot_LC_and_DB(X, net)
# Out:
# C:\Users\ritvikpalvankar7\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# -----------------------------------
# Hidden Layer Architecture:  16
# Learning Rate:  0.09
# Number of Epochs:  700
# Accuracy =  99.33 %
# -----------------------------------
# C:\Users\ritvikpalvankar7\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# -----------------------------------
# Hidden Layer Architecture:  16
# Learning Rate:  0.09
# Number of Epochs:  700
# Accuracy =  99.33 %
# -----------------------------------
# ...

# %% [markdown]
# # Learning rate for the graph below is 0.09 and the epoch is 700 with accuracy=99.33%

# %%
Image(r'C:\Users\ritvikpalvankar7\Desktop\FML\99.33 accuracy.png')

# %% [markdown]
# # 3.3

# %%
net_hidden_layers =[16,6] #
net_learning_rate =[0.05,0.05] #
epochs =[950,950]

for i in net_hidden_layers:
    for j in net_learning_rate:
        for k in epochs:
            net.set_params(hidden_layer_sizes = i, learning_rate_init = j, max_iter = k)
            net.fit(X, y)
            y_pred = net.predict(X)

            acc_score = accuracy_score(y, y_pred)
            print('-----------------------------------')
            print('Hidden Layer Architecture: ', i)
            print('Learning Rate: ', j)
            print('Number of Epochs: ', k)
            print('Accuracy = ', np.round(acc_score*100,2),'%')
            print('-----------------------------------')
            plot_LC_and_DB(X, net)
# Out:
# C:\Users\ritvikpalvankar7\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (950) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# -----------------------------------
# Hidden Layer Architecture:  16
# Learning Rate:  0.05
# Number of Epochs:  950
# Accuracy =  95.97 %
# -----------------------------------
# C:\Users\ritvikpalvankar7\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (950) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# -----------------------------------
# Hidden Layer Architecture:  16
# Learning Rate:  0.05
# Number of Epochs:  950
# Accuracy =  99.63 %
# -----------------------------------
# ...

# %% [markdown]
# # Learning rate for the graph below is 0.05 and the epoch is 950 with accuracy=99.63%

# %%
Image(r'C:\Users\ritvikpalvankar7\Desktop\FML\fig3.png')

# %% [markdown]
# ### 4

# %% [markdown]
# #  Hyperparameters:learning rate= 0.05 and epoch= 950. It can be seen that for the following hyperparameters we get good accuracy of 99.63% and hence we get a good decision boundary. The letters 'U' and 'F' are well separated. The learning rate controls the model learning rate. A very small value can cause  the training process to  take a lot of time and if  very large value is chosen then we can might miss the minimum and convergence is not possible. The number of epochs impacts the training process in a way such that if it is too large then we can overfit.
